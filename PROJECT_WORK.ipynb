# %%
import pandas as pd

# %%
df=pd.read_csv("mental_health_risk.csv")
df
# Out:
#        age  gender marital_status education_level employment_status  \
# 0       56   Other         Single        Bachelor        Unemployed
# 1       47    Male         Single        Bachelor        Unemployed
# 2       56  Female       Divorced        Bachelor           Student
# 3       59   Other        Married        Bachelor          Employed
# 4       58    Male         Single     High School     Self-Employed
# ...    ...     ...            ...             ...               ...
# 24995   36  Female         Single        Bachelor        Unemployed
# 24996   49  Female       Divorced          Master           Student
# 24997   35  Female        Married             PhD     Self-Employed
# 24998   44    Male       Divorced     High School           Student
# 24999   19    Male         Single          Master     Self-Employed
#
#        sleep_hours  physical_activity_hours_per_week  \
# 0              8.6                               2.8
# ...

# %%
df.head(5)
# Out:
#    age  gender marital_status education_level employment_status  sleep_hours  \
# 0   56   Other         Single        Bachelor        Unemployed          8.6
# 1   47    Male         Single        Bachelor        Unemployed          4.5
# 2   56  Female       Divorced        Bachelor           Student          3.1
# 3   59   Other        Married        Bachelor          Employed          7.0
# 4   58    Male         Single     High School     Self-Employed          5.1
#
#    physical_activity_hours_per_week  screen_time_hours_per_day  \
# 0                               2.8                        9.6
# 1                               2.7                        3.0
# 2                              14.1                        7.2
# 3                               0.5                       10.3
# 4                               2.5                        1.2
#
#    social_support_score  work_stress_level  ...  depression_score  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        age  gender marital_status education_level employment_status  \
# 0       56   Other         Single        Bachelor        Unemployed
# 1       47    Male         Single        Bachelor        Unemployed
# 2       56  Female       Divorced        Bachelor           Student
# 3       59   Other        Married        Bachelor          Employed
# 4       58    Male         Single     High School     Self-Employed
# ...    ...     ...            ...             ...               ...
# 24995   36  Female         Single        Bachelor        Unemployed
# 24996   49  Female       Divorced          Master           Student
# 24997   35  Female        Married             PhD     Self-Employed
# 24998   44    Male       Divorced     High School           Student
# 24999   19    Male         Single          Master     Self-Employed
#
#        sleep_hours  physical_activity_hours_per_week  \
# 0              8.6                               2.8
# ...

# %%
df.describe()
# Out:
#                 age   sleep_hours  physical_activity_hours_per_week  \
# count  25000.000000  25000.000000                      25000.000000
# mean      39.072560      6.509516                          7.515400
# std       12.404948      2.015586                          4.324346
# min       18.000000      3.000000                          0.000000
# 25%       28.000000      4.800000                          3.800000
# 50%       39.000000      6.500000                          7.500000
# 75%       50.000000      8.200000                         11.300000
# max       60.000000     10.000000                         15.000000
#
#        screen_time_hours_per_day  social_support_score  work_stress_level  \
# count               25000.000000           25000.00000       25000.000000
# mean                    6.469132               5.50840           5.517080
# std                     3.167682               2.88694           2.864548
# ...

# %%
df.isnull().sum()
# Out:
# age                                 0
# gender                              0
# marital_status                      0
# education_level                     0
# employment_status                   0
# sleep_hours                         0
# physical_activity_hours_per_week    0
# screen_time_hours_per_day           0
# social_support_score                0
# work_stress_level                   0
# academic_pressure_level             0
# job_satisfaction_score              0
# financial_stress_level              0
# working_hours_per_week              0
# anxiety_score                       0
# depression_score                    0
# stress_level                        0
# mood_swings_frequency               0
# concentration_difficulty_level      0
# panic_attack_history                0
# family_history_mental_illness       0
# previous_mental_health_diagnosis    0
# therapy_history                     0
# substance_use                       0
# mental_health_risk                  0
# ...

# %%
df.drop(columns=["physical_activity_hours_per_week","social_support_score","mood_swings_frequency","concentration_difficulty_level","substance_use"],inplace=True)
df
# Out:
#        age  gender marital_status education_level employment_status  \
# 0       56   Other         Single        Bachelor        Unemployed
# 1       47    Male         Single        Bachelor        Unemployed
# 2       56  Female       Divorced        Bachelor           Student
# 3       59   Other        Married        Bachelor          Employed
# 4       58    Male         Single     High School     Self-Employed
# ...    ...     ...            ...             ...               ...
# 24995   36  Female         Single        Bachelor        Unemployed
# 24996   49  Female       Divorced          Master           Student
# 24997   35  Female        Married             PhD     Self-Employed
# 24998   44    Male       Divorced     High School           Student
# 24999   19    Male         Single          Master     Self-Employed
#
#        sleep_hours  screen_time_hours_per_day  work_stress_level  \
# 0              8.6                        9.6                 10
# ...

# %%
import matplotlib.pyplot as plt

# %%
df["mental_health_risk"].value_counts().plot(kind="bar",color="brown")
plt.title("Mental Health",color="Orange")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
df["marital_status"].value_counts().plot(kind="pie")
plt.title("Marital status",color="Red")
plt.show()

# %%
df["working_hours_per_week"].value_counts().plot(kind="hist")
plt.show()
