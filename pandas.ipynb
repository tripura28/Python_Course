# %%
#pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
a=[10,20,30,40]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
b=[2.3,4.5,1.2,5.6]
pd.Series(b)
# Out:
# 0    2.3
# 1    4.5
# 2    1.2
# 3    5.6
# dtype: float64

# %%
c=["s","u","n","d","a","r","i"]
pd.Series(c)
# Out:
# 0    s
# 1    u
# 2    n
# 3    d
# 4    a
# 5    r
# 6    i
# dtype: str

# %%
x=[3+4j,5+6j]
pd.Series(x)
# Out:
# 0    3.0+4.0j
# 1    5.0+6.0j
# dtype: complex128

# %%
y=[True,False]
pd.Series(y)
# Out:
# 0     True
# 1    False
# dtype: bool

# %% [markdown]
# # DataFrame

# %%
data={"names":[10,20,30,40],
     "attendance":["P","A","A","A"]}
pd.DataFrame(data)
# Out:
#    names attendance
# 0     10          P
# 1     20          A
# 2     30          A
# 3     40          A

# %%
data={"names":["surya","gayee","keeru","deepu"],
      "subjects":["Maths","English","Physics","Chemistry"],
     "marks":[90,80,89,78],
     "percentages":[89.9,78.4,85.5,76.5]}
pd.DataFrame(data)
# Out:
#    names   subjects  marks  percentages
# 0  surya      Maths     90         89.9
# 1  gayee    English     80         78.4
# 2  keeru    Physics     89         85.5
# 3  deepu  Chemistry     78         76.5

# %%
data=pd.read_csv("Student_Report.csv")
data
# Out:
#      Names  Marks Grade
# 0    Jnana     88     B
# 1  Tripura     78     B
# 2  Sundari     90     A
# 3    Surya     98     A

# %%
data.columns
# Out:
# Index(['Names', 'Marks', 'Grade'], dtype='str')

# %%
data.shape
# Out:
# (4, 3)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Names  Marks Grade
# 0    Jnana     88     B
# 1  Tripura     78     B
# 2  Sundari     90     A
# 3    Surya     98     A>

# %%
data1=pd.read_csv("genz_social_media.csv")
data1
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 0        19    Male  Australia           2.658617         Snapchat
# 1        16  Female        USA           5.685387          Twitter
# 2        25  Female      India           2.782420           TikTok
# 3        27    Male      India           3.486598          YouTube
# 4        23  Female      India           3.748829           TikTok
# ...     ...     ...        ...                ...              ...
# 999995   21    Male      India           3.097065         Snapchat
# 999996   14    Male      India           3.663561        Instagram
# 999997   20    Male      India           4.474618          YouTube
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 0                        4         Education            29.222443
# ...

# %%
data1.head(5)
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %%
data1.columns
# Out:
# Index(['age', 'gender', 'country', 'daily_usage_hours', 'primary_platform',
#        'num_platforms_used', 'purpose', 'avg_session_minutes', 'night_usage',
#        'mental_health_score', 'addiction_level', 'screen_time_before_sleep'],
#       dtype='str')

# %%
data1.shape
# Out:
# (1000000, 12)

# %%
data1.info
# Out:
# <bound method DataFrame.info of         age  gender    country  daily_usage_hours primary_platform  \
# 0        19    Male  Australia           2.658617         Snapchat
# 1        16  Female        USA           5.685387          Twitter
# 2        25  Female      India           2.782420           TikTok
# 3        27    Male      India           3.486598          YouTube
# 4        23  Female      India           3.748829           TikTok
# ...     ...     ...        ...                ...              ...
# 999995   21    Male      India           3.097065         Snapchat
# 999996   14    Male      India           3.663561        Instagram
# 999997   20    Male      India           4.474618          YouTube
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# ...
