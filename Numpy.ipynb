# %% [markdown]
# # Numpy

# %% [raw]
# 1) 0 - Dimension:
# (50)
# 2) 1 - Dimension:
# ([1,2,3,4])
# 3) 2 - Dimension:
# ([[1,2,3],[4,5,6]])
# 4) 3 - Dimension:
# ([[[1,2,3],[4,5,6]],[[9,8,7],[6,5,4]]])

# %%
#pip install numpy

# %%
import numpy as np

# %%
a=np.array(80)
print(a)
print(type(a))
print(a.ndim)
# Out:
# 80
# <class 'numpy.ndarray'>
# 0

# %%
b=np.array([1,2,3,4])
print(b)
print(type(b))
print(b.ndim)
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# 1

# %%
c=np.array([[1,2,3],[4,5,5]])
print(c)
print(type(c))
print(c.ndim)
# Out:
# [[1 2 3]
#  [4 5 5]]
# <class 'numpy.ndarray'>
# 2

# %%
d=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(d)
print(type(d))
print(d.ndim)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# <class 'numpy.ndarray'>
# 3

# %% [raw]
#  #diff b/w list and array
# list:-
# We can only merge the values
# Array:-
# We can do operations

# %%
#list
a=[1,2,3,4]
b=[5,6,7,8]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#array
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
print(a+b)
# Out:
# [ 6  8 10 12]

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
print(a*b)
# Out:
# [ 5 12 21 32]

# %%
c=np.sum(a)
print(c)
# Out:
# 10

# %%
d=np.mean(a)
print(d)
# Out:
# 2.5
